# %%
import os
import pickle
import librosa
import librosa.display
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
class Loader:
    """Loader is responsible for loading an audio file."""

    def __init__(self, sample_rate, duration, mono):
        self.sample_rate = sample_rate
        self.duration = duration
        self.mono = mono

    def load(self, file_path):
        signal = librosa.load(file_path,
                              sr=None,
                              mono=self.mono)[0]
        return signal

# %%
class Padder:
    """Padder is responsible to apply padding to an array."""

    def __init__(self, mode="constant"):
        self.mode = mode

    def left_pad(self, array, num_missing_items):
        padded_array = np.pad(array,
                              (num_missing_items, 0),
                              mode=self.mode)
        return padded_array

    def right_pad(self, array, num_missing_items):
        padded_array = np.pad(array,
                              (0, num_missing_items),
                              mode=self.mode)
        return padded_array

# %%
class LogSpectrogramExtractor:
    """LogSpectrogramExtractor extracts log spectrograms (in dB) from a
    time-series signal.
    """

    def __init__(self, sr, fmin, n_bins, hop_length):
        self.hop_length = hop_length
        self.sr = sr
        self.fmin = fmin
        self.n_bins = n_bins

    def extract(self, signal):
        cqt = librosa.cqt(
            signal, 
            self.sr, 
            hop_length=self.hop_length, 
            window="hann", 
            fmin=self.fmin, 
            n_bins=self.n_bins
        )
        spectrogram = np.abs(cqt)
        log_spectrogram = librosa.amplitude_to_db(spectrogram)
        return log_spectrogram

# %%
class MinMaxNormaliser:
    """MinMaxNormaliser applies min max normalisation to an array."""

    def __init__(self, min_val, max_val):
        self.min = min_val
        self.max = max_val

    def normalise(self, array):
        norm_array = (array - array.min()) / (array.max() - array.min())
        norm_array = norm_array * (self.max - self.min) + self.min
        return norm_array

    def denormalise(self, norm_array, original_min, original_max):
        array = (norm_array - self.min) / (self.max - self.min)
        array = array * (original_max - original_min) + original_min
        return array

# %%
class Saver:
    """saver is responsible to save features, and the min max values."""

    def __init__(self, feature_save_dir, min_max_values_save_dir):
        self.feature_save_dir = feature_save_dir
        self.min_max_values_save_dir = min_max_values_save_dir

    def save_feature(self, feature, file_path):
        save_path = self._generate_save_path(file_path)
        np.save(save_path, feature)

    def save_min_max_values(self, min_max_values):
        save_path = os.path.join(self.min_max_values_save_dir,
                                 "min_max_values.pkl")
        self._save(min_max_values, save_path)

    @staticmethod
    def _save(data, save_path):
        with open(save_path, "wb") as f:
            pickle.dump(data, f)

    def _generate_save_path(self, file_path):
        file_name = os.path.split(file_path)[1]
        save_path = os.path.join(self.feature_save_dir, file_name + ".npy")
        return save_path

# %%
class PreprocessingPipeline:
    """PreprocessingPipeline processes audio files in a directory, applying
    the following steps to each file:
        1- load a file
        2- pad the signal (if necessary)
        3- extracting log spectrogram from signal
        4- normalise spectrogram
        5- save the normalised spectrogram
    Storing the min max values for all the log spectrograms.
    """

    def __init__(self):
        self.padder = None
        self.extractor = None
        self.normaliser = None
        self.saver = None
        self.min_max_values = {}
        self._loader = None
        self._num_expected_samples = None

    @property
    def loader(self):
        return self._loader

    @loader.setter
    def loader(self, loader):
        self._loader = loader
        self._num_expected_samples = int(loader.sample_rate * loader.duration)

    def process(self, audio_files_dir):
        for root, _, files in os.walk(audio_files_dir):
            for file in files:
                file_path = os.path.join(root, file)
                print(file_path)
                self._process_file(file_path)
                print(f"Processed file {file_path}")
        self.saver.save_min_max_values(self.min_max_values)

    def _process_file(self, file_path):
        signal = self.loader.load(file_path)
        if self._is_padding_necessary(signal):
            signal = self._apply_padding(signal)
        feature = self.extractor.extract(signal)
        norm_feature = self.normaliser.normalise(feature)
        save_path = self.saver.save_feature(norm_feature, file_path)
        self._store_min_max_value(save_path, feature.min(), feature.max())

    def _is_padding_necessary(self, signal):
        if len(signal) < self._num_expected_samples:
            return True
        return False

    def _apply_padding(self, signal):
        num_missing_samples = self._num_expected_samples - len(signal)
        padded_signal = self.padder.right_pad(signal, num_missing_samples)
        return padded_signal

    def _store_min_max_value(self, save_path, min_val, max_val):
        self.min_max_values[save_path] = {
            "min": min_val,
            "max": max_val
        }

# %%
def extract(signal, sr, hop_length, fmin, n_bins):
    cqt = librosa.cqt(
        signal, 
        sr, 
        hop_length=hop_length, 
        window="hann", 
        fmin=fmin, 
        n_bins=n_bins
    )
    spectrogram = np.abs(cqt)
    log_spectrogram = librosa.amplitude_to_db(spectrogram)
    return log_spectrogram

# %%
class Loader:
    """Loader is responsible for loading an audio file."""

    def __init__(self, sample_rate, duration, mono):
        self.sample_rate = sample_rate
        self.duration = duration
        self.mono = mono

    def load(self, file_path):
        signal = librosa.load(file_path,
                              sr=self.sample_rate,
                              mono=self.mono)[0]
        return signal

# %%
HOP_LENGTH = 512
N_BINS = 64
FMIN = librosa.note_to_hz('C0')
DURATION = 2.72  # in seconds
SAMPLE_RATE = 48000
MONO = True

SPECTROGRAMS_SAVE_DIR = "spectrograms/"
MIN_MAX_VALUES_SAVE_DIR = "fsdd/"
FILES_DIR = "audios/"

# instantiate all objects
loader = Loader(SAMPLE_RATE, DURATION, MONO)
padder = Padder()
log_spectrogram_extractor = LogSpectrogramExtractor(SAMPLE_RATE, FMIN, N_BINS, HOP_LENGTH)
min_max_normaliser = MinMaxNormaliser(0, 1)
saver = Saver(SPECTROGRAMS_SAVE_DIR, MIN_MAX_VALUES_SAVE_DIR)

preprocessing_pipeline = PreprocessingPipeline()
preprocessing_pipeline.loader = loader
preprocessing_pipeline.padder = padder
preprocessing_pipeline.extractor = log_spectrogram_extractor
preprocessing_pipeline.normaliser = min_max_normaliser
preprocessing_pipeline.saver = saver

preprocessing_pipeline.process(FILES_DIR)
# Out:
# audios/track_0.wav
# Processed file audios/track_0.wav
# audios/track_1.wav
# Processed file audios/track_1.wav
# audios/track_10.wav
# Processed file audios/track_10.wav
# audios/track_100.wav
# Processed file audios/track_100.wav
# audios/track_101.wav
# Processed file audios/track_101.wav
# audios/track_102.wav
# Processed file audios/track_102.wav
# audios/track_103.wav
# Processed file audios/track_103.wav
# audios/track_104.wav
# Processed file audios/track_104.wav
# audios/track_105.wav
# Processed file audios/track_105.wav
# audios/track_106.wav
# Processed file audios/track_106.wav
# audios/track_107.wav
# Processed file audios/track_107.wav
# audios/track_108.wav
# Processed file audios/track_108.wav
# audios/track_109.wav
# Processed file audios/track_109.wav
# audios/track_11.wav
# Processed file audios/track_11.wav
# audios/track_110.wav
# Processed file audios/track_110.wav
# audios/track_111.wav
# Processed file audios/track_111.wav
# audios/track_112.wav
# Processed file audios/track_112.wav
# audios/track_113.wav
# Processed file audios/track_113.wav
# audios/track_114.wav
# Processed file audios/track_114.wav
# audios/track_115.wav
# Processed file audios/track_115.wav
# audios/track_116.wav
# Processed file audios/track_116.wav
# audios/track_117.wav
# Processed file audios/track_117.wav
# audios/track_118.wav
# Processed file audios/track_118.wav
# audios/track_119.wav
# Processed file audios/track_119.wav
# audios/track_12.wav
# Processed file audios/track_12.wav
# audios/track_120.wav
# Processed file audios/track_120.wav
# audios/track_121.wav
# Processed file audios/track_121.wav
# audios/track_122.wav
# Processed file audios/track_122.wav
# audios/track_123.wav
# Processed file audios/track_123.wav
# audios/track_124.wav
# Processed file audios/track_124.wav
# audios/track_125.wav
# Processed file audios/track_125.wav
# audios/track_126.wav
# Processed file audios/track_126.wav
# audios/track_127.wav
# Processed file audios/track_127.wav
# audios/track_128.wav
# Processed file audios/track_128.wav
# audios/track_129.wav
# Processed file audios/track_129.wav
# audios/track_13.wav
# Processed file audios/track_13.wav
# audios/track_130.wav
# Processed file audios/track_130.wav
# audios/track_131.wav
# Processed file audios/track_131.wav
# audios/track_132.wav
# Processed file audios/track_132.wav
# audios/track_133.wav
# Processed file audios/track_133.wav
# audios/track_134.wav
# Processed file audios/track_134.wav
# audios/track_135.wav
# Processed file audios/track_135.wav
# audios/track_136.wav
# Processed file audios/track_136.wav
# audios/track_137.wav
# Processed file audios/track_137.wav
# audios/track_138.wav
# Processed file audios/track_138.wav
# audios/track_139.wav
# Processed file audios/track_139.wav
# audios/track_14.wav
# Processed file audios/track_14.wav
# audios/track_140.wav
# Processed file audios/track_140.wav
# audios/track_141.wav
# Processed file audios/track_141.wav
# audios/track_142.wav
# Processed file audios/track_142.wav
# audios/track_143.wav
# Processed file audios/track_143.wav
# audios/track_144.wav
# Processed file audios/track_144.wav
# audios/track_145.wav
# Processed file audios/track_145.wav
# audios/track_146.wav
# Processed file audios/track_146.wav
# audios/track_147.wav
# Processed file audios/track_147.wav
# audios/track_148.wav
# Processed file audios/track_148.wav
# audios/track_149.wav
# Processed file audios/track_149.wav
# audios/track_15.wav
# Processed file audios/track_15.wav
# audios/track_150.wav
# Processed file audios/track_150.wav
# audios/track_151.wav
# Processed file audios/track_151.wav
# audios/track_152.wav
# Processed file audios/track_152.wav
# audios/track_153.wav
# Processed file audios/track_153.wav
# audios/track_154.wav
# Processed file audios/track_154.wav
# audios/track_155.wav
# Processed file audios/track_155.wav
# audios/track_156.wav
# Processed file audios/track_156.wav
# audios/track_157.wav
# Processed file audios/track_157.wav
# audios/track_158.wav
# Processed file audios/track_158.wav
# audios/track_159.wav
# Processed file audios/track_159.wav
# audios/track_16.wav
# Processed file audios/track_16.wav
# audios/track_160.wav
# Processed file audios/track_160.wav
# audios/track_161.wav
# Processed file audios/track_161.wav
# audios/track_162.wav
# Processed file audios/track_162.wav
# audios/track_163.wav
# Processed file audios/track_163.wav
# audios/track_164.wav
# Processed file audios/track_164.wav
# audios/track_165.wav
# Processed file audios/track_165.wav
# audios/track_166.wav
# Processed file audios/track_166.wav
# audios/track_167.wav
# Processed file audios/track_167.wav
# audios/track_168.wav
# Processed file audios/track_168.wav
# audios/track_169.wav
# Processed file audios/track_169.wav
# audios/track_17.wav
# Processed file audios/track_17.wav
# audios/track_170.wav
# Processed file audios/track_170.wav
# audios/track_171.wav
# Processed file audios/track_171.wav
# audios/track_172.wav
# Processed file audios/track_172.wav
# audios/track_173.wav
# Processed file audios/track_173.wav
# audios/track_174.wav
# Processed file audios/track_174.wav
# audios/track_175.wav
# Processed file audios/track_175.wav
# audios/track_176.wav
# Processed file audios/track_176.wav
# audios/track_177.wav
# Processed file audios/track_177.wav
# audios/track_178.wav
# Processed file audios/track_178.wav
# audios/track_179.wav
# Processed file audios/track_179.wav
# audios/track_18.wav
# Processed file audios/track_18.wav
# audios/track_180.wav
# Processed file audios/track_180.wav
# audios/track_181.wav
# Processed file audios/track_181.wav
# audios/track_182.wav
# Processed file audios/track_182.wav
# audios/track_183.wav
# Processed file audios/track_183.wav
# audios/track_184.wav
# Processed file audios/track_184.wav
# audios/track_185.wav
# Processed file audios/track_185.wav
# audios/track_186.wav
# Processed file audios/track_186.wav
# audios/track_187.wav
# Processed file audios/track_187.wav
# audios/track_188.wav
# Processed file audios/track_188.wav
# audios/track_189.wav
# Processed file audios/track_189.wav
# audios/track_19.wav
# Processed file audios/track_19.wav
# audios/track_190.wav
# Processed file audios/track_190.wav
# audios/track_191.wav
# Processed file audios/track_191.wav
# audios/track_192.wav
# Processed file audios/track_192.wav
# audios/track_193.wav
# Processed file audios/track_193.wav
# audios/track_194.wav
# Processed file audios/track_194.wav
# audios/track_195.wav
# Processed file audios/track_195.wav
# audios/track_196.wav
# Processed file audios/track_196.wav
# audios/track_197.wav
# Processed file audios/track_197.wav
# audios/track_198.wav
# Processed file audios/track_198.wav
# audios/track_199.wav
# Processed file audios/track_199.wav
# audios/track_2.wav
# Processed file audios/track_2.wav
# audios/track_20.wav
# Processed file audios/track_20.wav
# audios/track_200.wav
# Processed file audios/track_200.wav
# audios/track_201.wav
# Processed file audios/track_201.wav
# audios/track_202.wav
# Processed file audios/track_202.wav
# audios/track_203.wav
# Processed file audios/track_203.wav
# audios/track_204.wav
# Processed file audios/track_204.wav
# audios/track_205.wav
# Processed file audios/track_205.wav
# audios/track_206.wav
# Processed file audios/track_206.wav
# audios/track_207.wav
# Processed file audios/track_207.wav
# audios/track_208.wav
# Processed file audios/track_208.wav
# audios/track_209.wav
# Processed file audios/track_209.wav
# audios/track_21.wav
# Processed file audios/track_21.wav
# audios/track_210.wav
# Processed file audios/track_210.wav
# audios/track_211.wav
# Processed file audios/track_211.wav
# audios/track_212.wav
# Processed file audios/track_212.wav
# audios/track_213.wav
# Processed file audios/track_213.wav
# audios/track_214.wav
# Processed file audios/track_214.wav
# audios/track_215.wav
# Processed file audios/track_215.wav
# audios/track_216.wav
# Processed file audios/track_216.wav
# audios/track_217.wav
# Processed file audios/track_217.wav
# audios/track_218.wav
# Processed file audios/track_218.wav
# audios/track_219.wav
# Processed file audios/track_219.wav
# audios/track_22.wav
# Processed file audios/track_22.wav
# audios/track_220.wav
# Processed file audios/track_220.wav
# audios/track_221.wav
# Processed file audios/track_221.wav
# audios/track_222.wav
# Processed file audios/track_222.wav
# audios/track_223.wav
# Processed file audios/track_223.wav
# audios/track_224.wav
# Processed file audios/track_224.wav
# audios/track_225.wav
# Processed file audios/track_225.wav
# audios/track_226.wav
# Processed file audios/track_226.wav
# audios/track_227.wav
# Processed file audios/track_227.wav
# audios/track_228.wav
# Processed file audios/track_228.wav
# audios/track_229.wav
# Processed file audios/track_229.wav
# audios/track_23.wav
# Processed file audios/track_23.wav
# audios/track_230.wav
# Processed file audios/track_230.wav
# audios/track_231.wav
# Processed file audios/track_231.wav
# audios/track_232.wav
# Processed file audios/track_232.wav
# audios/track_233.wav
# Processed file audios/track_233.wav
# audios/track_234.wav
# Processed file audios/track_234.wav
# audios/track_235.wav
# Processed file audios/track_235.wav
# audios/track_236.wav
# Processed file audios/track_236.wav
# audios/track_237.wav
# Processed file audios/track_237.wav
# audios/track_238.wav
# Processed file audios/track_238.wav
# audios/track_239.wav
# Processed file audios/track_239.wav
# audios/track_24.wav
# Processed file audios/track_24.wav
# audios/track_240.wav
# Processed file audios/track_240.wav
# audios/track_241.wav
# Processed file audios/track_241.wav
# audios/track_242.wav
# Processed file audios/track_242.wav
# audios/track_243.wav
# Processed file audios/track_243.wav
# audios/track_244.wav
# Processed file audios/track_244.wav
# audios/track_245.wav
# Processed file audios/track_245.wav
# audios/track_246.wav
# Processed file audios/track_246.wav
# audios/track_247.wav
# Processed file audios/track_247.wav
# audios/track_248.wav
# Processed file audios/track_248.wav
# audios/track_249.wav
# Processed file audios/track_249.wav
# audios/track_25.wav
# Processed file audios/track_25.wav
# audios/track_250.wav
# Processed file audios/track_250.wav
# audios/track_251.wav
# Processed file audios/track_251.wav
# audios/track_252.wav
# Processed file audios/track_252.wav
# audios/track_253.wav
# Processed file audios/track_253.wav
# audios/track_254.wav
# Processed file audios/track_254.wav
# audios/track_255.wav
# Processed file audios/track_255.wav
# audios/track_256.wav
# Processed file audios/track_256.wav
# audios/track_257.wav
# Processed file audios/track_257.wav
# audios/track_258.wav
# Processed file audios/track_258.wav
# audios/track_259.wav
# Processed file audios/track_259.wav
# audios/track_26.wav
# Processed file audios/track_26.wav
# audios/track_260.wav
# Processed file audios/track_260.wav
# audios/track_261.wav
# Processed file audios/track_261.wav
# audios/track_262.wav
# Processed file audios/track_262.wav
# audios/track_263.wav
# Processed file audios/track_263.wav
# audios/track_264.wav
# Processed file audios/track_264.wav
# audios/track_265.wav
# Processed file audios/track_265.wav
# audios/track_266.wav
# Processed file audios/track_266.wav
# audios/track_267.wav
# Processed file audios/track_267.wav
# audios/track_268.wav
# Processed file audios/track_268.wav
# audios/track_269.wav
# Processed file audios/track_269.wav
# audios/track_27.wav
# Processed file audios/track_27.wav
# audios/track_270.wav
# Processed file audios/track_270.wav
# audios/track_271.wav
# Processed file audios/track_271.wav
# audios/track_272.wav
# Processed file audios/track_272.wav
# audios/track_273.wav
# Processed file audios/track_273.wav
# audios/track_274.wav
# Processed file audios/track_274.wav
# audios/track_275.wav
# Processed file audios/track_275.wav
# audios/track_276.wav
# Processed file audios/track_276.wav
# audios/track_277.wav
# Processed file audios/track_277.wav
# audios/track_278.wav
# Processed file audios/track_278.wav
# audios/track_279.wav
# Processed file audios/track_279.wav
# audios/track_28.wav
# Processed file audios/track_28.wav
# audios/track_280.wav
# Processed file audios/track_280.wav
# audios/track_281.wav
# Processed file audios/track_281.wav
# audios/track_282.wav
# Processed file audios/track_282.wav
# audios/track_283.wav
# Processed file audios/track_283.wav
# audios/track_284.wav
# Processed file audios/track_284.wav
# audios/track_285.wav
# Processed file audios/track_285.wav
# audios/track_286.wav
# Processed file audios/track_286.wav
# audios/track_287.wav
# Processed file audios/track_287.wav
# audios/track_288.wav
# Processed file audios/track_288.wav
# audios/track_289.wav
# Processed file audios/track_289.wav
# audios/track_29.wav
# Processed file audios/track_29.wav
# audios/track_290.wav
# Processed file audios/track_290.wav
# audios/track_291.wav
# Processed file audios/track_291.wav
# audios/track_292.wav
# Processed file audios/track_292.wav
# audios/track_293.wav
# Processed file audios/track_293.wav
# audios/track_294.wav
# Processed file audios/track_294.wav
# audios/track_295.wav
# Processed file audios/track_295.wav
# audios/track_296.wav
# Processed file audios/track_296.wav
# audios/track_297.wav
# Processed file audios/track_297.wav
# audios/track_298.wav
# Processed file audios/track_298.wav
# audios/track_299.wav
# Processed file audios/track_299.wav
# audios/track_3.wav
# Processed file audios/track_3.wav
# audios/track_30.wav
# Processed file audios/track_30.wav
# audios/track_300.wav
# Processed file audios/track_300.wav
# audios/track_301.wav
# Processed file audios/track_301.wav
# audios/track_302.wav
# Processed file audios/track_302.wav
# audios/track_303.wav
# Processed file audios/track_303.wav
# audios/track_304.wav
# Processed file audios/track_304.wav
# audios/track_305.wav
# Processed file audios/track_305.wav
# audios/track_306.wav
# Processed file audios/track_306.wav
# audios/track_307.wav
# Processed file audios/track_307.wav
# audios/track_308.wav
# Processed file audios/track_308.wav
# audios/track_309.wav
# Processed file audios/track_309.wav
# audios/track_31.wav
# Processed file audios/track_31.wav
# audios/track_310.wav
# Processed file audios/track_310.wav
# audios/track_311.wav
# Processed file audios/track_311.wav
# audios/track_312.wav
# Processed file audios/track_312.wav
# audios/track_313.wav
# Processed file audios/track_313.wav
# audios/track_314.wav
# Processed file audios/track_314.wav
# audios/track_315.wav
# Processed file audios/track_315.wav
# audios/track_316.wav
# Processed file audios/track_316.wav
# audios/track_317.wav
# Processed file audios/track_317.wav
# audios/track_318.wav
# Processed file audios/track_318.wav
# audios/track_319.wav
# Processed file audios/track_319.wav
# audios/track_32.wav
# Processed file audios/track_32.wav
# audios/track_320.wav
# Processed file audios/track_320.wav
# audios/track_321.wav
# Processed file audios/track_321.wav
# audios/track_322.wav
# Processed file audios/track_322.wav
# audios/track_323.wav
# Processed file audios/track_323.wav
# audios/track_324.wav
# Processed file audios/track_324.wav
# audios/track_325.wav
# Processed file audios/track_325.wav
# audios/track_326.wav
# Processed file audios/track_326.wav
# audios/track_327.wav
# Processed file audios/track_327.wav
# audios/track_328.wav
# Processed file audios/track_328.wav
# audios/track_329.wav
# Processed file audios/track_329.wav
# audios/track_33.wav
# Processed file audios/track_33.wav
# audios/track_330.wav
# Processed file audios/track_330.wav
# audios/track_331.wav
# Processed file audios/track_331.wav
# audios/track_332.wav
# Processed file audios/track_332.wav
# audios/track_333.wav
# Processed file audios/track_333.wav
# audios/track_334.wav
# Processed file audios/track_334.wav
# audios/track_335.wav
# Processed file audios/track_335.wav
# audios/track_336.wav
# Processed file audios/track_336.wav
# audios/track_337.wav
# Processed file audios/track_337.wav
# audios/track_338.wav
# Processed file audios/track_338.wav
# audios/track_339.wav
# Processed file audios/track_339.wav
# audios/track_34.wav
# Processed file audios/track_34.wav
# audios/track_340.wav
# Processed file audios/track_340.wav
# audios/track_341.wav
# Processed file audios/track_341.wav
# audios/track_342.wav
# Processed file audios/track_342.wav
# audios/track_343.wav
# Processed file audios/track_343.wav
# audios/track_344.wav
# Processed file audios/track_344.wav
# audios/track_345.wav
# Processed file audios/track_345.wav
# audios/track_346.wav
# Processed file audios/track_346.wav
# audios/track_347.wav
# Processed file audios/track_347.wav
# audios/track_348.wav
# Processed file audios/track_348.wav
# audios/track_349.wav
# Processed file audios/track_349.wav
# audios/track_35.wav
# Processed file audios/track_35.wav
# audios/track_350.wav
# Processed file audios/track_350.wav
# audios/track_351.wav
# Processed file audios/track_351.wav
# audios/track_352.wav
# Processed file audios/track_352.wav
# audios/track_353.wav
# Processed file audios/track_353.wav
# audios/track_354.wav
# Processed file audios/track_354.wav
# audios/track_355.wav
# Processed file audios/track_355.wav
# audios/track_356.wav
# Processed file audios/track_356.wav
# audios/track_357.wav
# Processed file audios/track_357.wav
# audios/track_358.wav
# Processed file audios/track_358.wav
# audios/track_359.wav
# Processed file audios/track_359.wav
# audios/track_36.wav
# Processed file audios/track_36.wav
# audios/track_360.wav
# Processed file audios/track_360.wav
# audios/track_361.wav
# Processed file audios/track_361.wav
# audios/track_362.wav
# Processed file audios/track_362.wav
# audios/track_363.wav
# Processed file audios/track_363.wav
# audios/track_364.wav
# Processed file audios/track_364.wav
# audios/track_365.wav
# Processed file audios/track_365.wav
# audios/track_366.wav
# Processed file audios/track_366.wav
# audios/track_367.wav
# Processed file audios/track_367.wav
# audios/track_368.wav
# Processed file audios/track_368.wav
# audios/track_369.wav
# Processed file audios/track_369.wav
# audios/track_37.wav
# Processed file audios/track_37.wav
# audios/track_370.wav
# Processed file audios/track_370.wav
# audios/track_371.wav
# Processed file audios/track_371.wav
# audios/track_372.wav
# Processed file audios/track_372.wav
# audios/track_373.wav
# Processed file audios/track_373.wav
# audios/track_374.wav
# Processed file audios/track_374.wav
# audios/track_375.wav
# Processed file audios/track_375.wav
# audios/track_376.wav
# Processed file audios/track_376.wav
# audios/track_377.wav
# Processed file audios/track_377.wav
# audios/track_378.wav
# Processed file audios/track_378.wav
# audios/track_379.wav
# Processed file audios/track_379.wav
# audios/track_38.wav
# Processed file audios/track_38.wav
# audios/track_380.wav
# Processed file audios/track_380.wav
# audios/track_381.wav
# Processed file audios/track_381.wav
# audios/track_382.wav
# Processed file audios/track_382.wav
# audios/track_383.wav
# Processed file audios/track_383.wav
# audios/track_384.wav
# Processed file audios/track_384.wav
# audios/track_385.wav
# Processed file audios/track_385.wav
# audios/track_386.wav
# Processed file audios/track_386.wav
# audios/track_387.wav
# Processed file audios/track_387.wav
# audios/track_388.wav
# Processed file audios/track_388.wav
# audios/track_389.wav
# Processed file audios/track_389.wav
# audios/track_39.wav
# Processed file audios/track_39.wav
# audios/track_390.wav
# Processed file audios/track_390.wav
# audios/track_391.wav
# Processed file audios/track_391.wav
# audios/track_392.wav
# Processed file audios/track_392.wav
# audios/track_393.wav
# Processed file audios/track_393.wav
# audios/track_394.wav
# Processed file audios/track_394.wav
# audios/track_395.wav
# Processed file audios/track_395.wav
# audios/track_396.wav
# Processed file audios/track_396.wav
# audios/track_397.wav
# Processed file audios/track_397.wav
# audios/track_398.wav
# Processed file audios/track_398.wav
# audios/track_399.wav
# Processed file audios/track_399.wav
# audios/track_4.wav
# Processed file audios/track_4.wav
# audios/track_40.wav
# Processed file audios/track_40.wav
# audios/track_400.wav
# Processed file audios/track_400.wav
# audios/track_401.wav
# Processed file audios/track_401.wav
# audios/track_402.wav
# Processed file audios/track_402.wav
# audios/track_403.wav
# Processed file audios/track_403.wav
# audios/track_404.wav
# Processed file audios/track_404.wav
# audios/track_405.wav
# Processed file audios/track_405.wav
# audios/track_406.wav
# Processed file audios/track_406.wav
# audios/track_407.wav
# Processed file audios/track_407.wav
# audios/track_408.wav
# Processed file audios/track_408.wav
# audios/track_409.wav
# Processed file audios/track_409.wav
# audios/track_41.wav
# Processed file audios/track_41.wav
# audios/track_410.wav
# Processed file audios/track_410.wav
# audios/track_411.wav
# Processed file audios/track_411.wav
# audios/track_412.wav
# Processed file audios/track_412.wav
# audios/track_413.wav
# Processed file audios/track_413.wav
# audios/track_414.wav
# Processed file audios/track_414.wav
# audios/track_415.wav
# Processed file audios/track_415.wav
# audios/track_416.wav
# Processed file audios/track_416.wav
# audios/track_417.wav
# Processed file audios/track_417.wav
# audios/track_418.wav
# Processed file audios/track_418.wav
# audios/track_419.wav
# Processed file audios/track_419.wav
# audios/track_42.wav
# Processed file audios/track_42.wav
# audios/track_420.wav
# Processed file audios/track_420.wav
# audios/track_421.wav
# Processed file audios/track_421.wav
# audios/track_422.wav
# Processed file audios/track_422.wav
# audios/track_423.wav
# Processed file audios/track_423.wav
# audios/track_424.wav
# Processed file audios/track_424.wav
# audios/track_425.wav
# Processed file audios/track_425.wav
# audios/track_426.wav
# Processed file audios/track_426.wav
# audios/track_427.wav
# Processed file audios/track_427.wav
# audios/track_428.wav
# Processed file audios/track_428.wav
# audios/track_429.wav
# Processed file audios/track_429.wav
# audios/track_43.wav
# Processed file audios/track_43.wav
# audios/track_430.wav
# Processed file audios/track_430.wav
# audios/track_431.wav
# Processed file audios/track_431.wav
# audios/track_432.wav
# Processed file audios/track_432.wav
# audios/track_433.wav
# Processed file audios/track_433.wav
# audios/track_434.wav
# Processed file audios/track_434.wav
# audios/track_435.wav
# Processed file audios/track_435.wav
# audios/track_436.wav
# Processed file audios/track_436.wav
# audios/track_437.wav
# Processed file audios/track_437.wav
# audios/track_438.wav
# Processed file audios/track_438.wav
# audios/track_439.wav
# Processed file audios/track_439.wav
# audios/track_44.wav
# Processed file audios/track_44.wav
# audios/track_440.wav
# Processed file audios/track_440.wav
# audios/track_441.wav
# Processed file audios/track_441.wav
# audios/track_442.wav
# Processed file audios/track_442.wav
# audios/track_443.wav
# Processed file audios/track_443.wav
# audios/track_444.wav
# Processed file audios/track_444.wav
# audios/track_445.wav
# Processed file audios/track_445.wav
# audios/track_446.wav
# Processed file audios/track_446.wav
# audios/track_447.wav
# Processed file audios/track_447.wav
# audios/track_448.wav
# Processed file audios/track_448.wav
# audios/track_449.wav
# Processed file audios/track_449.wav
# audios/track_45.wav
# Processed file audios/track_45.wav
# audios/track_450.wav
# Processed file audios/track_450.wav
# audios/track_451.wav
# Processed file audios/track_451.wav
# audios/track_452.wav
# Processed file audios/track_452.wav
# audios/track_453.wav
# Processed file audios/track_453.wav
# audios/track_454.wav
# Processed file audios/track_454.wav
# audios/track_455.wav
# Processed file audios/track_455.wav
# audios/track_456.wav
# Processed file audios/track_456.wav
# audios/track_457.wav
# Processed file audios/track_457.wav
# audios/track_458.wav
# Processed file audios/track_458.wav
# audios/track_459.wav
# Processed file audios/track_459.wav
# audios/track_46.wav
# Processed file audios/track_46.wav
# audios/track_460.wav
# Processed file audios/track_460.wav
# audios/track_461.wav
# Processed file audios/track_461.wav
# audios/track_462.wav
# Processed file audios/track_462.wav
# audios/track_463.wav
# Processed file audios/track_463.wav
# audios/track_464.wav
# Processed file audios/track_464.wav
# audios/track_465.wav
# Processed file audios/track_465.wav
# audios/track_466.wav
# Processed file audios/track_466.wav
# audios/track_467.wav
# Processed file audios/track_467.wav
# audios/track_468.wav
# Processed file audios/track_468.wav
# audios/track_469.wav
# Processed file audios/track_469.wav
# audios/track_47.wav
# Processed file audios/track_47.wav
# audios/track_470.wav
# Processed file audios/track_470.wav
# audios/track_471.wav
# Processed file audios/track_471.wav
# audios/track_472.wav
# Processed file audios/track_472.wav
# audios/track_473.wav
# Processed file audios/track_473.wav
# audios/track_474.wav
# Processed file audios/track_474.wav
# audios/track_475.wav
# Processed file audios/track_475.wav
# audios/track_476.wav
# Processed file audios/track_476.wav
# audios/track_477.wav
# Processed file audios/track_477.wav
# audios/track_478.wav
# Processed file audios/track_478.wav
# audios/track_479.wav
# Processed file audios/track_479.wav
# audios/track_48.wav
# Processed file audios/track_48.wav
# audios/track_480.wav
# Processed file audios/track_480.wav
# audios/track_481.wav
# Processed file audios/track_481.wav
# audios/track_482.wav
# Processed file audios/track_482.wav
# audios/track_483.wav
# Processed file audios/track_483.wav
# audios/track_484.wav
# Processed file audios/track_484.wav
# audios/track_485.wav
# Processed file audios/track_485.wav
# audios/track_486.wav
# Processed file audios/track_486.wav
# audios/track_487.wav
# Processed file audios/track_487.wav
# audios/track_488.wav
# Processed file audios/track_488.wav
# audios/track_489.wav
# Processed file audios/track_489.wav
# audios/track_49.wav
# Processed file audios/track_49.wav
# audios/track_490.wav
# Processed file audios/track_490.wav
# audios/track_491.wav
# Processed file audios/track_491.wav
# audios/track_492.wav
# Processed file audios/track_492.wav
# audios/track_493.wav
# Processed file audios/track_493.wav
# audios/track_494.wav
# Processed file audios/track_494.wav
# audios/track_495.wav
# Processed file audios/track_495.wav
# audios/track_496.wav
# Processed file audios/track_496.wav
# audios/track_497.wav
# Processed file audios/track_497.wav
# audios/track_498.wav
# Processed file audios/track_498.wav
# audios/track_499.wav
# Processed file audios/track_499.wav
# audios/track_5.wav
# Processed file audios/track_5.wav
# audios/track_50.wav
# Processed file audios/track_50.wav
# audios/track_500.wav
# Processed file audios/track_500.wav
# audios/track_501.wav
# Processed file audios/track_501.wav
# audios/track_502.wav
# Processed file audios/track_502.wav
# audios/track_503.wav
# Processed file audios/track_503.wav
# audios/track_504.wav
# Processed file audios/track_504.wav
# audios/track_505.wav
# Processed file audios/track_505.wav
# audios/track_506.wav
# Processed file audios/track_506.wav
# audios/track_507.wav
# Processed file audios/track_507.wav
# audios/track_508.wav
# Processed file audios/track_508.wav
# audios/track_509.wav
# Processed file audios/track_509.wav
# audios/track_51.wav
# Processed file audios/track_51.wav
# audios/track_510.wav
# Processed file audios/track_510.wav
# audios/track_511.wav
# Processed file audios/track_511.wav
# audios/track_512.wav
# Processed file audios/track_512.wav
# audios/track_513.wav
# Processed file audios/track_513.wav
# audios/track_514.wav
# Processed file audios/track_514.wav
# audios/track_515.wav
# Processed file audios/track_515.wav
# audios/track_516.wav
# Processed file audios/track_516.wav
# audios/track_517.wav
# Processed file audios/track_517.wav
# audios/track_518.wav
# Processed file audios/track_518.wav
# audios/track_519.wav
# Processed file audios/track_519.wav
# audios/track_52.wav
# Processed file audios/track_52.wav
# audios/track_520.wav
# Processed file audios/track_520.wav
# audios/track_521.wav
# Processed file audios/track_521.wav
# audios/track_522.wav
# Processed file audios/track_522.wav
# audios/track_523.wav
# Processed file audios/track_523.wav
# audios/track_524.wav
# Processed file audios/track_524.wav
# audios/track_525.wav
# Processed file audios/track_525.wav
# audios/track_526.wav
# Processed file audios/track_526.wav
# audios/track_527.wav
# Processed file audios/track_527.wav
# audios/track_528.wav
# Processed file audios/track_528.wav
# audios/track_529.wav
# Processed file audios/track_529.wav
# audios/track_53.wav
# Processed file audios/track_53.wav
# audios/track_530.wav
# Processed file audios/track_530.wav
# audios/track_531.wav
# Processed file audios/track_531.wav
# audios/track_532.wav
# Processed file audios/track_532.wav
# audios/track_533.wav
# Processed file audios/track_533.wav
# audios/track_534.wav
# Processed file audios/track_534.wav
# audios/track_535.wav
# Processed file audios/track_535.wav
# audios/track_536.wav
# Processed file audios/track_536.wav
# audios/track_537.wav
# Processed file audios/track_537.wav
# audios/track_538.wav
# Processed file audios/track_538.wav
# audios/track_539.wav
# Processed file audios/track_539.wav
# audios/track_54.wav
# Processed file audios/track_54.wav
# audios/track_540.wav
# Processed file audios/track_540.wav
# audios/track_541.wav
# Processed file audios/track_541.wav
# audios/track_542.wav
# Processed file audios/track_542.wav
# audios/track_543.wav
# Processed file audios/track_543.wav
# audios/track_544.wav
# Processed file audios/track_544.wav
# audios/track_545.wav
# Processed file audios/track_545.wav
# audios/track_546.wav
# Processed file audios/track_546.wav
# audios/track_547.wav
# Processed file audios/track_547.wav
# audios/track_548.wav
# Processed file audios/track_548.wav
# audios/track_549.wav
# Processed file audios/track_549.wav
# audios/track_55.wav
# Processed file audios/track_55.wav
# audios/track_550.wav
# Processed file audios/track_550.wav
# audios/track_551.wav
# Processed file audios/track_551.wav
# audios/track_552.wav
# Processed file audios/track_552.wav
# audios/track_553.wav
# Processed file audios/track_553.wav
# audios/track_554.wav
# Processed file audios/track_554.wav
# audios/track_555.wav
# Processed file audios/track_555.wav
# audios/track_556.wav
# Processed file audios/track_556.wav
# audios/track_557.wav
# Processed file audios/track_557.wav
# audios/track_558.wav
# Processed file audios/track_558.wav
# audios/track_559.wav
# Processed file audios/track_559.wav
# audios/track_56.wav
# Processed file audios/track_56.wav
# audios/track_560.wav
# Processed file audios/track_560.wav
# audios/track_561.wav
# Processed file audios/track_561.wav
# audios/track_562.wav
# Processed file audios/track_562.wav
# audios/track_563.wav
# Processed file audios/track_563.wav
# audios/track_564.wav
# Processed file audios/track_564.wav
# audios/track_565.wav
# Processed file audios/track_565.wav
# audios/track_566.wav
# Processed file audios/track_566.wav
# audios/track_567.wav
# Processed file audios/track_567.wav
# audios/track_568.wav
# Processed file audios/track_568.wav
# audios/track_569.wav
# Processed file audios/track_569.wav
# audios/track_57.wav
# Processed file audios/track_57.wav
# audios/track_570.wav
# Processed file audios/track_570.wav
# audios/track_571.wav
# Processed file audios/track_571.wav
# audios/track_572.wav
# Processed file audios/track_572.wav
# audios/track_573.wav
# Processed file audios/track_573.wav
# audios/track_574.wav
# Processed file audios/track_574.wav
# audios/track_575.wav
# Processed file audios/track_575.wav
# audios/track_576.wav
# Processed file audios/track_576.wav
# audios/track_577.wav
# Processed file audios/track_577.wav
# audios/track_578.wav
# Processed file audios/track_578.wav
# audios/track_579.wav
# Processed file audios/track_579.wav
# audios/track_58.wav
# Processed file audios/track_58.wav
# audios/track_580.wav
# Processed file audios/track_580.wav
# audios/track_581.wav
# Processed file audios/track_581.wav
# audios/track_582.wav
# Processed file audios/track_582.wav
# audios/track_583.wav
# Processed file audios/track_583.wav
# audios/track_584.wav
# Processed file audios/track_584.wav
# audios/track_585.wav
# Processed file audios/track_585.wav
# audios/track_586.wav
# Processed file audios/track_586.wav
# audios/track_587.wav
# Processed file audios/track_587.wav
# audios/track_588.wav
# Processed file audios/track_588.wav
# audios/track_589.wav
# Processed file audios/track_589.wav
# audios/track_59.wav
# Processed file audios/track_59.wav
# audios/track_590.wav
# Processed file audios/track_590.wav
# audios/track_591.wav
# Processed file audios/track_591.wav
# audios/track_592.wav
# Processed file audios/track_592.wav
# audios/track_593.wav
# Processed file audios/track_593.wav
# audios/track_594.wav
# Processed file audios/track_594.wav
# audios/track_595.wav
# Processed file audios/track_595.wav
# audios/track_596.wav
# Processed file audios/track_596.wav
# audios/track_597.wav
# Processed file audios/track_597.wav
# audios/track_598.wav
# Processed file audios/track_598.wav
# audios/track_599.wav
# Processed file audios/track_599.wav
# audios/track_6.wav
# Processed file audios/track_6.wav
# audios/track_60.wav
# Processed file audios/track_60.wav
# audios/track_600.wav
# Processed file audios/track_600.wav
# audios/track_601.wav
# Processed file audios/track_601.wav
# audios/track_602.wav
# Processed file audios/track_602.wav
# audios/track_603.wav
# Processed file audios/track_603.wav
# audios/track_604.wav
# Processed file audios/track_604.wav
# audios/track_605.wav
# Processed file audios/track_605.wav
# audios/track_606.wav
# Processed file audios/track_606.wav
# audios/track_607.wav
# Processed file audios/track_607.wav
# audios/track_608.wav
# Processed file audios/track_608.wav
# audios/track_609.wav
# Processed file audios/track_609.wav
# audios/track_61.wav
# Processed file audios/track_61.wav
# audios/track_610.wav
# Processed file audios/track_610.wav
# audios/track_611.wav
# Processed file audios/track_611.wav
# audios/track_612.wav
# Processed file audios/track_612.wav
# audios/track_613.wav
# Processed file audios/track_613.wav
# audios/track_614.wav
# Processed file audios/track_614.wav
# audios/track_615.wav
# Processed file audios/track_615.wav
# audios/track_616.wav
# Processed file audios/track_616.wav
# audios/track_617.wav
# Processed file audios/track_617.wav
# audios/track_618.wav
# Processed file audios/track_618.wav
# audios/track_619.wav
# Processed file audios/track_619.wav
# audios/track_62.wav
# Processed file audios/track_62.wav
# audios/track_620.wav
# Processed file audios/track_620.wav
# audios/track_621.wav
# Processed file audios/track_621.wav
# audios/track_622.wav
# Processed file audios/track_622.wav
# audios/track_623.wav
# Processed file audios/track_623.wav
# audios/track_624.wav
# Processed file audios/track_624.wav
# audios/track_625.wav
# Processed file audios/track_625.wav
# audios/track_626.wav
# Processed file audios/track_626.wav
# audios/track_627.wav
# Processed file audios/track_627.wav
# audios/track_628.wav
# Processed file audios/track_628.wav
# audios/track_629.wav
# Processed file audios/track_629.wav
# audios/track_63.wav
# Processed file audios/track_63.wav
# audios/track_630.wav
# Processed file audios/track_630.wav
# audios/track_631.wav
# Processed file audios/track_631.wav
# audios/track_632.wav
# Processed file audios/track_632.wav
# audios/track_633.wav
# Processed file audios/track_633.wav
# audios/track_634.wav
# Processed file audios/track_634.wav
# audios/track_635.wav
# Processed file audios/track_635.wav
# audios/track_636.wav
# Processed file audios/track_636.wav
# audios/track_637.wav
# Processed file audios/track_637.wav
# audios/track_638.wav
# Processed file audios/track_638.wav
# audios/track_639.wav
# Processed file audios/track_639.wav
# audios/track_64.wav
# Processed file audios/track_64.wav
# audios/track_640.wav
# Processed file audios/track_640.wav
# audios/track_641.wav
# Processed file audios/track_641.wav
# audios/track_642.wav
# Processed file audios/track_642.wav
# audios/track_643.wav
# Processed file audios/track_643.wav
# audios/track_644.wav
# Processed file audios/track_644.wav
# audios/track_645.wav
# Processed file audios/track_645.wav
# audios/track_646.wav
# Processed file audios/track_646.wav
# audios/track_647.wav
# Processed file audios/track_647.wav
# audios/track_648.wav
# Processed file audios/track_648.wav
# audios/track_649.wav
# Processed file audios/track_649.wav
# audios/track_65.wav
# Processed file audios/track_65.wav
# audios/track_650.wav
# Processed file audios/track_650.wav
# audios/track_651.wav
# Processed file audios/track_651.wav
# audios/track_652.wav
# Processed file audios/track_652.wav
# audios/track_653.wav
# Processed file audios/track_653.wav
# audios/track_654.wav
# Processed file audios/track_654.wav
# audios/track_655.wav
# Processed file audios/track_655.wav
# audios/track_656.wav
# Processed file audios/track_656.wav
# audios/track_657.wav
# Processed file audios/track_657.wav
# audios/track_658.wav
# Processed file audios/track_658.wav
# audios/track_659.wav
# Processed file audios/track_659.wav
# audios/track_66.wav
# Processed file audios/track_66.wav
# audios/track_660.wav
# Processed file audios/track_660.wav
# audios/track_661.wav
# Processed file audios/track_661.wav
# audios/track_662.wav
# Processed file audios/track_662.wav
# audios/track_663.wav
# Processed file audios/track_663.wav
# audios/track_664.wav
# Processed file audios/track_664.wav
# audios/track_665.wav
# Processed file audios/track_665.wav
# audios/track_666.wav
# Processed file audios/track_666.wav
# audios/track_667.wav
# Processed file audios/track_667.wav
# audios/track_668.wav
# Processed file audios/track_668.wav
# audios/track_669.wav
# Processed file audios/track_669.wav
# audios/track_67.wav
# Processed file audios/track_67.wav
# audios/track_670.wav
# Processed file audios/track_670.wav
# audios/track_671.wav
# Processed file audios/track_671.wav
# audios/track_672.wav
# Processed file audios/track_672.wav
# audios/track_673.wav
# Processed file audios/track_673.wav
# audios/track_674.wav
# Processed file audios/track_674.wav
# audios/track_675.wav
# Processed file audios/track_675.wav
# audios/track_676.wav
# Processed file audios/track_676.wav
# audios/track_677.wav
# Processed file audios/track_677.wav
# audios/track_678.wav
# Processed file audios/track_678.wav
# audios/track_679.wav
# Processed file audios/track_679.wav
# audios/track_68.wav
# Processed file audios/track_68.wav
# audios/track_680.wav
# Processed file audios/track_680.wav
# audios/track_681.wav
# Processed file audios/track_681.wav
# audios/track_682.wav
# Processed file audios/track_682.wav
# audios/track_683.wav
# Processed file audios/track_683.wav
# audios/track_684.wav
# Processed file audios/track_684.wav
# audios/track_685.wav
# Processed file audios/track_685.wav
# audios/track_686.wav
# Processed file audios/track_686.wav
# audios/track_687.wav
# Processed file audios/track_687.wav
# audios/track_688.wav
# Processed file audios/track_688.wav
# audios/track_689.wav
# Processed file audios/track_689.wav
# audios/track_69.wav
# Processed file audios/track_69.wav
# audios/track_690.wav
# Processed file audios/track_690.wav
# audios/track_691.wav
# Processed file audios/track_691.wav
# audios/track_692.wav
# Processed file audios/track_692.wav
# audios/track_693.wav
# Processed file audios/track_693.wav
# audios/track_694.wav
# Processed file audios/track_694.wav
# audios/track_695.wav
# Processed file audios/track_695.wav
# audios/track_696.wav
# Processed file audios/track_696.wav
# audios/track_697.wav
# Processed file audios/track_697.wav
# audios/track_698.wav
# Processed file audios/track_698.wav
# audios/track_699.wav
# Processed file audios/track_699.wav
# audios/track_7.wav
# Processed file audios/track_7.wav
# audios/track_70.wav
# Processed file audios/track_70.wav
# audios/track_700.wav
# Processed file audios/track_700.wav
# audios/track_701.wav
# Processed file audios/track_701.wav
# audios/track_702.wav
# Processed file audios/track_702.wav
# audios/track_703.wav
# Processed file audios/track_703.wav
# audios/track_704.wav
# Processed file audios/track_704.wav
# audios/track_705.wav
# Processed file audios/track_705.wav
# audios/track_706.wav
# Processed file audios/track_706.wav
# audios/track_707.wav
# Processed file audios/track_707.wav
# audios/track_708.wav
# Processed file audios/track_708.wav
# audios/track_709.wav
# Processed file audios/track_709.wav
# audios/track_71.wav
# Processed file audios/track_71.wav
# audios/track_710.wav
# Processed file audios/track_710.wav
# audios/track_711.wav
# Processed file audios/track_711.wav
# audios/track_712.wav
# Processed file audios/track_712.wav
# audios/track_713.wav
# Processed file audios/track_713.wav
# audios/track_714.wav
# Processed file audios/track_714.wav
# audios/track_715.wav
# Processed file audios/track_715.wav
# audios/track_716.wav
# Processed file audios/track_716.wav
# audios/track_717.wav
# Processed file audios/track_717.wav
# audios/track_718.wav
# Processed file audios/track_718.wav
# audios/track_719.wav
# Processed file audios/track_719.wav
# audios/track_72.wav
# Processed file audios/track_72.wav
# audios/track_720.wav
# Processed file audios/track_720.wav
# audios/track_721.wav
# Processed file audios/track_721.wav
# audios/track_722.wav
# Processed file audios/track_722.wav
# audios/track_723.wav
# Processed file audios/track_723.wav
# audios/track_724.wav
# Processed file audios/track_724.wav
# audios/track_725.wav
# Processed file audios/track_725.wav
# audios/track_726.wav
# Processed file audios/track_726.wav
# audios/track_727.wav
# Processed file audios/track_727.wav
# audios/track_728.wav
# Processed file audios/track_728.wav
# audios/track_729.wav
# Processed file audios/track_729.wav
# audios/track_73.wav
# Processed file audios/track_73.wav
# audios/track_730.wav
# Processed file audios/track_730.wav
# audios/track_731.wav
# Processed file audios/track_731.wav
# audios/track_732.wav
# Processed file audios/track_732.wav
# audios/track_733.wav
# Processed file audios/track_733.wav
# audios/track_734.wav
# Processed file audios/track_734.wav
# audios/track_735.wav
# Processed file audios/track_735.wav
# audios/track_736.wav
# Processed file audios/track_736.wav
# audios/track_737.wav
# Processed file audios/track_737.wav
# audios/track_738.wav
# Processed file audios/track_738.wav
# audios/track_739.wav
# Processed file audios/track_739.wav
# audios/track_74.wav
# Processed file audios/track_74.wav
# audios/track_740.wav
# Processed file audios/track_740.wav
# audios/track_741.wav
# Processed file audios/track_741.wav
# audios/track_742.wav
# Processed file audios/track_742.wav
# audios/track_743.wav
# Processed file audios/track_743.wav
# audios/track_744.wav
# Processed file audios/track_744.wav
# audios/track_745.wav
# Processed file audios/track_745.wav
# audios/track_746.wav
# Processed file audios/track_746.wav
# audios/track_747.wav
# Processed file audios/track_747.wav
# audios/track_748.wav
# Processed file audios/track_748.wav
# audios/track_749.wav
# Processed file audios/track_749.wav
# audios/track_75.wav
# Processed file audios/track_75.wav
# audios/track_750.wav
# Processed file audios/track_750.wav
# audios/track_751.wav
# Processed file audios/track_751.wav
# audios/track_752.wav
# Processed file audios/track_752.wav
# audios/track_753.wav
# Processed file audios/track_753.wav
# audios/track_754.wav
# Processed file audios/track_754.wav
# audios/track_755.wav
# Processed file audios/track_755.wav
# audios/track_756.wav
# Processed file audios/track_756.wav
# audios/track_757.wav
# Processed file audios/track_757.wav
# audios/track_758.wav
# Processed file audios/track_758.wav
# audios/track_759.wav
# Processed file audios/track_759.wav
# audios/track_76.wav
# Processed file audios/track_76.wav
# audios/track_760.wav
# Processed file audios/track_760.wav
# audios/track_761.wav
# Processed file audios/track_761.wav
# audios/track_762.wav
# Processed file audios/track_762.wav
# audios/track_763.wav
# Processed file audios/track_763.wav
# audios/track_764.wav
# Processed file audios/track_764.wav
# audios/track_765.wav
# Processed file audios/track_765.wav
# audios/track_766.wav
# Processed file audios/track_766.wav
# audios/track_767.wav
# Processed file audios/track_767.wav
# audios/track_768.wav
# Processed file audios/track_768.wav
# audios/track_769.wav
# Processed file audios/track_769.wav
# audios/track_77.wav
# Processed file audios/track_77.wav
# audios/track_770.wav
# Processed file audios/track_770.wav
# audios/track_771.wav
# Processed file audios/track_771.wav
# audios/track_772.wav
# Processed file audios/track_772.wav
# audios/track_773.wav
# Processed file audios/track_773.wav
# audios/track_774.wav
# Processed file audios/track_774.wav
# audios/track_775.wav
# Processed file audios/track_775.wav
# audios/track_776.wav
# Processed file audios/track_776.wav
# audios/track_777.wav
# Processed file audios/track_777.wav
# audios/track_778.wav
# Processed file audios/track_778.wav
# audios/track_779.wav
# Processed file audios/track_779.wav
# audios/track_78.wav
# Processed file audios/track_78.wav
# audios/track_780.wav
# Processed file audios/track_780.wav
# audios/track_781.wav
# Processed file audios/track_781.wav
# audios/track_782.wav
# Processed file audios/track_782.wav
# audios/track_783.wav
# Processed file audios/track_783.wav
# audios/track_784.wav
# Processed file audios/track_784.wav
# audios/track_785.wav
# Processed file audios/track_785.wav
# audios/track_786.wav
# Processed file audios/track_786.wav
# audios/track_787.wav
# Processed file audios/track_787.wav
# audios/track_788.wav
# Processed file audios/track_788.wav
# audios/track_789.wav
# Processed file audios/track_789.wav
# audios/track_79.wav
# Processed file audios/track_79.wav
# audios/track_790.wav
# Processed file audios/track_790.wav
# audios/track_791.wav
# Processed file audios/track_791.wav
# audios/track_792.wav
# Processed file audios/track_792.wav
# audios/track_793.wav
# Processed file audios/track_793.wav
# audios/track_794.wav
# Processed file audios/track_794.wav
# audios/track_795.wav
# Processed file audios/track_795.wav
# audios/track_796.wav
# Processed file audios/track_796.wav
# audios/track_797.wav
# Processed file audios/track_797.wav
# audios/track_798.wav
# Processed file audios/track_798.wav
# audios/track_799.wav
# Processed file audios/track_799.wav
# audios/track_8.wav
# Processed file audios/track_8.wav
# audios/track_80.wav
# Processed file audios/track_80.wav
# audios/track_800.wav
# Processed file audios/track_800.wav
# audios/track_801.wav
# Processed file audios/track_801.wav
# audios/track_802.wav
# Processed file audios/track_802.wav
# audios/track_803.wav
# Processed file audios/track_803.wav
# audios/track_804.wav
# Processed file audios/track_804.wav
# audios/track_805.wav
# Processed file audios/track_805.wav
# audios/track_806.wav
# Processed file audios/track_806.wav
# audios/track_807.wav
# Processed file audios/track_807.wav
# audios/track_808.wav
# Processed file audios/track_808.wav
# audios/track_809.wav
# Processed file audios/track_809.wav
# audios/track_81.wav
# Processed file audios/track_81.wav
# audios/track_810.wav
# Processed file audios/track_810.wav
# audios/track_811.wav
# Processed file audios/track_811.wav
# audios/track_812.wav
# Processed file audios/track_812.wav
# audios/track_813.wav
# Processed file audios/track_813.wav
# audios/track_814.wav
# Processed file audios/track_814.wav
# audios/track_815.wav
# Processed file audios/track_815.wav
# audios/track_816.wav
# Processed file audios/track_816.wav
# audios/track_817.wav
# Processed file audios/track_817.wav
# audios/track_818.wav
# Processed file audios/track_818.wav
# audios/track_819.wav
# Processed file audios/track_819.wav
# audios/track_82.wav
# Processed file audios/track_82.wav
# audios/track_820.wav
# Processed file audios/track_820.wav
# audios/track_821.wav
# Processed file audios/track_821.wav
# audios/track_822.wav
# Processed file audios/track_822.wav
# audios/track_823.wav
# Processed file audios/track_823.wav
# audios/track_824.wav
# Processed file audios/track_824.wav
# audios/track_825.wav
# Processed file audios/track_825.wav
# audios/track_826.wav
# Processed file audios/track_826.wav
# audios/track_827.wav
# Processed file audios/track_827.wav
# audios/track_828.wav
# Processed file audios/track_828.wav
# audios/track_829.wav
# Processed file audios/track_829.wav
# audios/track_83.wav
# Processed file audios/track_83.wav
# audios/track_830.wav
# Processed file audios/track_830.wav
# audios/track_831.wav
# Processed file audios/track_831.wav
# audios/track_832.wav
# Processed file audios/track_832.wav
# audios/track_833.wav
# Processed file audios/track_833.wav
# audios/track_834.wav
# Processed file audios/track_834.wav
# audios/track_835.wav
# Processed file audios/track_835.wav
# audios/track_836.wav
# Processed file audios/track_836.wav
# audios/track_837.wav
# Processed file audios/track_837.wav
# audios/track_838.wav
# Processed file audios/track_838.wav
# audios/track_839.wav
# Processed file audios/track_839.wav
# audios/track_84.wav
# Processed file audios/track_84.wav
# audios/track_840.wav
# Processed file audios/track_840.wav
# audios/track_841.wav
# Processed file audios/track_841.wav
# audios/track_842.wav
# Processed file audios/track_842.wav
# audios/track_843.wav
# Processed file audios/track_843.wav
# audios/track_844.wav
# Processed file audios/track_844.wav
# audios/track_845.wav
# Processed file audios/track_845.wav
# audios/track_846.wav
# Processed file audios/track_846.wav
# audios/track_847.wav
# Processed file audios/track_847.wav
# audios/track_848.wav
# Processed file audios/track_848.wav
# audios/track_849.wav
# Processed file audios/track_849.wav
# audios/track_85.wav
# Processed file audios/track_85.wav
# audios/track_850.wav
# Processed file audios/track_850.wav
# audios/track_851.wav
# Processed file audios/track_851.wav
# audios/track_852.wav
# Processed file audios/track_852.wav
# audios/track_853.wav
# Processed file audios/track_853.wav
# audios/track_854.wav
# Processed file audios/track_854.wav
# audios/track_855.wav
# Processed file audios/track_855.wav
# audios/track_856.wav
# Processed file audios/track_856.wav
# audios/track_857.wav
# Processed file audios/track_857.wav
# audios/track_858.wav
# Processed file audios/track_858.wav
# audios/track_859.wav
# Processed file audios/track_859.wav
# audios/track_86.wav
# Processed file audios/track_86.wav
# audios/track_860.wav
# Processed file audios/track_860.wav
# audios/track_861.wav
# Processed file audios/track_861.wav
# audios/track_862.wav
# Processed file audios/track_862.wav
# audios/track_863.wav
# Processed file audios/track_863.wav
# audios/track_864.wav
# Processed file audios/track_864.wav
# audios/track_865.wav
# Processed file audios/track_865.wav
# audios/track_866.wav
# Processed file audios/track_866.wav
# audios/track_867.wav
# Processed file audios/track_867.wav
# audios/track_868.wav
# Processed file audios/track_868.wav
# audios/track_869.wav
# Processed file audios/track_869.wav
# audios/track_87.wav
# Processed file audios/track_87.wav
# audios/track_870.wav
# Processed file audios/track_870.wav
# audios/track_871.wav
# Processed file audios/track_871.wav
# audios/track_872.wav
# Processed file audios/track_872.wav
# audios/track_873.wav
# Processed file audios/track_873.wav
# audios/track_874.wav
# Processed file audios/track_874.wav
# audios/track_875.wav
# Processed file audios/track_875.wav
# audios/track_876.wav
# Processed file audios/track_876.wav
# audios/track_877.wav
# Processed file audios/track_877.wav
# audios/track_878.wav
# Processed file audios/track_878.wav
# audios/track_879.wav
# Processed file audios/track_879.wav
# audios/track_88.wav
# Processed file audios/track_88.wav
# audios/track_880.wav
# Processed file audios/track_880.wav
# audios/track_881.wav
# Processed file audios/track_881.wav
# audios/track_882.wav
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in true_divide
#   if __name__ == '__main__':
# Processed file audios/track_882.wav
# audios/track_89.wav
# Processed file audios/track_89.wav
# audios/track_9.wav
# Processed file audios/track_9.wav
# audios/track_90.wav
# Processed file audios/track_90.wav
# audios/track_91.wav
# Processed file audios/track_91.wav
# audios/track_92.wav
# Processed file audios/track_92.wav
# audios/track_93.wav
# Processed file audios/track_93.wav
# audios/track_94.wav
# Processed file audios/track_94.wav
# audios/track_95.wav
# Processed file audios/track_95.wav
# audios/track_96.wav
# Processed file audios/track_96.wav
# audios/track_97.wav
# Processed file audios/track_97.wav
# audios/track_98.wav
# Processed file audios/track_98.wav
# audios/track_99.wav
# Processed file audios/track_99.wav

# %%
librosa.display.specshow(np.load("spectrograms/opm.mp3.npy"))

# %%
np.load("spectrograms/track_0.wav.npy").shape
# Out:
# (72, 216)

# %% [markdown]
# ## Cut audios

# %%
import soundfile as sf

# %%
y, sr = librosa.load("topNCS_merged.wav", mono=True, sr=None)

# %%
DURATION = 2.72
HOP_LENGTH = int(DURATION * sr)

# %%
frames = librosa.util.frame(y, frame_length=int(DURATION * sr), hop_length=HOP_LENGTH)

# %%
for index, frame in enumerate(frames.T):
    sf.write(f'audios/track_{index}.wav', frame, 44100, 'PCM_24')

# %%
def load_fsdd(spectrograms_path):
    x_train = []
    for root, _, file_names in os.walk(spectrograms_path):
        for file_name in file_names:
            file_path = os.path.join(root, file_name)
            spectrogram = np.load(file_path) # (n_bins, frames, 1)
            if np.any(np.isnan(spectrogram)):
                print(file_name)
            x_train.append(spectrogram)
    x_train = np.array(x_train)
    return x_train

# %%
os.remove("spectrograms/.DS_Store")

# %%
x_train = load_fsdd("spectrograms/")

# %%
for i, j in enumerate(x_train):
    if np.any(np.isnan(j)):
        print("NAN")
        print(i)
# Out:
# NAN
# 867
# NAN
# 868

# %%
assert not
